# %%
# %run app.py
# Out:
# === Тест CSV ===
#
# === Загрузка CSV с автоопределением типов ===
# Имя	Возраст	Зарплата
# Алиса	30	50000
# Иван	25	45000
# Тимур	35	60000
# Денис	40	70000
# Определенные типы столбцов: {'Имя': <class 'str'>, 'Возраст': <class 'int'>, 'Зарплата': <class 'int'>}
#
# === Тест Pickle ===
#
# === Загрузка Pickle с автоопределением типов ===
# Имя	Возраст	Зарплата
# Алиса	30	50000
# Иван	25	45000
# Тимур	35	60000
# Денис	40	70000
# Определенные типы столбцов: {'Имя': <class 'str'>, 'Возраст': <class 'int'>, 'Зарплата': <class 'int'>}
#
# === Тест Text ===
# Таблица сохранена в текстовый файл: test_table.txt
#
# === Тест операций над таблицей ===
#
# Строки с 1 по 3:
# Имя	Возраст	Зарплата
# Алиса	30	50000
# Иван	25	45000
# Тимур	35	60000
#
# Строка, где Имя = 'Иван':
# Имя	Возраст	Зарплата
# Иван	25	45000
#
# Типы столбцов:
# {0: <class 'str'>, 1: <class 'int'>, 2: <class 'int'>}
#
# Установка типов столбцов:
# Имя	Возраст	Зарплата
# Алиса	30	50000.0
# Иван	25	45000.0
# Тимур	35	60000.0
# ...
